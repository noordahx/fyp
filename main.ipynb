# %%
import torch
import os
import numpy as np
import pandas as pd

from mia_lib.config import load_config
from mia_lib.data import get_cifar10_dataloaders, create_subset_dataloader
from mia_lib.models import create_model
from mia_lib.trainer import train_model
from mia_lib.attack.shadow_training import train_shadow_models
from mia_lib.attack.dataset_preparation import create_attack_dataset
from mia_lib.attack.train_attack_model import train_attack_model

# %% [markdown]
# ### Load config.

# %%
config = load_config("configs/mia_config.yaml")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Get dataset

# %%
trainset, testset, trainloader, testloader = get_cifar10_dataloaders(config)
print("Dataset loaded...")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Dataset loaded...

# %% [markdown]
# ### Train (or load existing) target model (resnet18 in our case) on a subset of the test set.

# %%
target_model = create_model(config).to(device)
os.makedirs(config["paths"]["model_save_dir"], exist_ok=True)

target_model_path = os.path.join(config["paths"]["model_save_dir"], "target_model.pth")

if os.path.exists(target_model_path):
    print(f"Target model checkpoint found at {target_model_path}. Loading...")
    target_model.load_state_dict(torch.load(target_model_path))
else:
    print(f"No target model checkoint found, Training a new one at {target_model_path}")
    # subset indices
    total_test_indices = np.arange(len(testset))
    
    # some MIA research workfloas reserve a "train" portion for shadow models. So, train model on test subset
    target_train_indices = np.random.choice(
        total_test_indices,
        config["training"]["train_subset_size"],
        replace=False
    )

    remaining_after_train = np.setdiff1d(total_test_indices, target_train_indices)
    target_eval_indices = np.random.choice(
        remaining_after_train,
        config["training"]["eval_subset_size"],
        replace=False
    )

    subset_tgt_train_loader = create_subset_dataloader(
        testset,
        target_train_indices,
        batch_size=config["training"]["train_batch_size"],
        shuffle=True,
        num_workers=config["training"]["num_workers"]
    )

    subset_tgt_eval_loader = create_subset_dataloader(
        testset,
        target_eval_indices,
        batch_size=config["training"]["eval_batch_size"],
        shuffle=False,
        num_workers=config["training"]["num_workers"]
    )

    best_acc, best_loss = train_model(
        target_model,
        subset_tgt_train_loader,
        subset_tgt_eval_loader,
        config,
        device,
        target_model_path
    )

    print(f"Target Model => Best Val Acc: {best_acc:.4f}%, Best Val Loss: {best_loss:.4f}")
# Out:
# Target model checkpoint found at ./models/target_model.pth. Loading...
# /tmp/ipykernel_10295/1237008118.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   target_model.load_state_dict(torch.load(target_model_path))

# %% [markdown]
# ### Train (or load) shadow models on the training set of CIFAR-10.

# %%
shadow_models = train_shadow_models(config, trainset, device)
# Out:
# [Shadow 0] Loaded existing indices from ./shadow_indices/shadow_indices_0.npz
# [Shadow 0] Found checkpoint at ./shadow_models/shadow_model_0.pth. Loading...
# [Shadow 1] Loaded existing indices from ./shadow_indices/shadow_indices_1.npz
# /home/acer/projects/fyp/mia_lib/attack/shadow_training.py:71: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   shadow_model.load_state_dict(torch.load(save_path, map_location=device))
# [Shadow 1] Found checkpoint at ./shadow_models/shadow_model_1.pth. Loading...
# [Shadow 2] Loaded existing indices from ./shadow_indices/shadow_indices_2.npz
# [Shadow 2] Found checkpoint at ./shadow_models/shadow_model_2.pth. Loading...
# [Shadow 3] Loaded existing indices from ./shadow_indices/shadow_indices_3.npz
# [Shadow 3] Found checkpoint at ./shadow_models/shadow_model_3.pth. Loading...
# [Shadow 4] Loaded existing indices from ./shadow_indices/shadow_indices_4.npz
# [Shadow 4] Found checkpoint at ./shadow_models/shadow_model_4.pth. Loading...
# [Shadow 5] Loaded existing indices from ./shadow_indices/shadow_indices_5.npz
# [Shadow 5] Found checkpoint at ./shadow_models/shadow_model_5.pth. Loading...
# [Shadow 6] Loaded existing indices from ./shadow_indices/shadow_indices_6.npz
# [Shadow 6] Found checkpoint at ./shadow_models/shadow_model_6.pth. Loading...
# [Shadow 7] Loaded existing indices from ./shadow_indices/shadow_indices_7.npz
# [Shadow 7] Found checkpoint at ./shadow_models/shadow_model_7.pth. Loading...
# [Shadow 8] Loaded existing indices from ./shadow_indices/shadow_indices_8.npz
# [Shadow 8] Found checkpoint at ./shadow_models/shadow_model_8.pth. Loading...
# [Shadow 9] Loaded existing indices from ./shadow_indices/shadow_indices_9.npz
# [Shadow 9] Found checkpoint at ./shadow_models/shadow_model_9.pth. Loading...
# [Shadow 10] Loaded existing indices from ./shadow_indices/shadow_indices_10.npz
# [Shadow 10] Found checkpoint at ./shadow_models/shadow_model_10.pth. Loading...
# [Shadow 11] Loaded existing indices from ./shadow_indices/shadow_indices_11.npz
# [Shadow 11] Found checkpoint at ./shadow_models/shadow_model_11.pth. Loading...
# [Shadow 12] Loaded existing indices from ./shadow_indices/shadow_indices_12.npz
# [Shadow 12] Found checkpoint at ./shadow_models/shadow_model_12.pth. Loading...
# [Shadow 13] Loaded existing indices from ./shadow_indices/shadow_indices_13.npz
# [Shadow 13] Found checkpoint at ./shadow_models/shadow_model_13.pth. Loading...
# [Shadow 14] Loaded existing indices from ./shadow_indices/shadow_indices_14.npz
# [Shadow 14] Found checkpoint at ./shadow_models/shadow_model_14.pth. Loading...
# [Shadow 15] Loaded existing indices from ./shadow_indices/shadow_indices_15.npz
# [Shadow 15] Found checkpoint at ./shadow_models/shadow_model_15.pth. Loading...
# [Shadow 16] Loaded existing indices from ./shadow_indices/shadow_indices_16.npz
# [Shadow 16] Found checkpoint at ./shadow_models/shadow_model_16.pth. Loading...
# [Shadow 17] Loaded existing indices from ./shadow_indices/shadow_indices_17.npz
# [Shadow 17] Found checkpoint at ./shadow_models/shadow_model_17.pth. Loading...
# [Shadow 18] Loaded existing indices from ./shadow_indices/shadow_indices_18.npz
# [Shadow 18] Found checkpoint at ./shadow_models/shadow_model_18.pth. Loading...
# [Shadow 19] Loaded existing indices from ./shadow_indices/shadow_indices_19.npz
# [Shadow 19] Found checkpoint at ./shadow_models/shadow_model_19.pth. Loading...
# [Shadow 20] Loaded existing indices from ./shadow_indices/shadow_indices_20.npz
# [Shadow 20] Found checkpoint at ./shadow_models/shadow_model_20.pth. Loading...
# [Shadow 21] Loaded existing indices from ./shadow_indices/shadow_indices_21.npz
# [Shadow 21] Found checkpoint at ./shadow_models/shadow_model_21.pth. Loading...
# [Shadow 22] Loaded existing indices from ./shadow_indices/shadow_indices_22.npz
# [Shadow 22] Found checkpoint at ./shadow_models/shadow_model_22.pth. Loading...
# [Shadow 23] Loaded existing indices from ./shadow_indices/shadow_indices_23.npz
# [Shadow 23] Found checkpoint at ./shadow_models/shadow_model_23.pth. Loading...
# [Shadow 24] Loaded existing indices from ./shadow_indices/shadow_indices_24.npz
# [Shadow 24] Found checkpoint at ./shadow_models/shadow_model_24.pth. Loading...
# [Shadow 25] Loaded existing indices from ./shadow_indices/shadow_indices_25.npz
# [Shadow 25] Found checkpoint at ./shadow_models/shadow_model_25.pth. Loading...
# [Shadow 26] Loaded existing indices from ./shadow_indices/shadow_indices_26.npz
# [Shadow 26] Found checkpoint at ./shadow_models/shadow_model_26.pth. Loading...
# [Shadow 27] Loaded existing indices from ./shadow_indices/shadow_indices_27.npz
# [Shadow 27] Found checkpoint at ./shadow_models/shadow_model_27.pth. Loading...
# [Shadow 28] Loaded existing indices from ./shadow_indices/shadow_indices_28.npz
# [Shadow 28] Found checkpoint at ./shadow_models/shadow_model_28.pth. Loading...
# [Shadow 29] Loaded existing indices from ./shadow_indices/shadow_indices_29.npz
# [Shadow 29] Found checkpoint at ./shadow_models/shadow_model_29.pth. Loading...
# [Shadow 30] Loaded existing indices from ./shadow_indices/shadow_indices_30.npz
# [Shadow 30] Found checkpoint at ./shadow_models/shadow_model_30.pth. Loading...
# [Shadow 31] Loaded existing indices from ./shadow_indices/shadow_indices_31.npz
# [Shadow 31] Found checkpoint at ./shadow_models/shadow_model_31.pth. Loading...
# [Shadow 32] Loaded existing indices from ./shadow_indices/shadow_indices_32.npz
# [Shadow 32] Found checkpoint at ./shadow_models/shadow_model_32.pth. Loading...
# [Shadow 33] Loaded existing indices from ./shadow_indices/shadow_indices_33.npz
# [Shadow 33] Found checkpoint at ./shadow_models/shadow_model_33.pth. Loading...
# [Shadow 34] Loaded existing indices from ./shadow_indices/shadow_indices_34.npz
# [Shadow 34] Found checkpoint at ./shadow_models/shadow_model_34.pth. Loading...
# [Shadow 35] Loaded existing indices from ./shadow_indices/shadow_indices_35.npz
# [Shadow 35] Found checkpoint at ./shadow_models/shadow_model_35.pth. Loading...
# [Shadow 36] Loaded existing indices from ./shadow_indices/shadow_indices_36.npz
# [Shadow 36] Found checkpoint at ./shadow_models/shadow_model_36.pth. Loading...
# [Shadow 37] Loaded existing indices from ./shadow_indices/shadow_indices_37.npz
# [Shadow 37] Found checkpoint at ./shadow_models/shadow_model_37.pth. Loading...
# [Shadow 38] Loaded existing indices from ./shadow_indices/shadow_indices_38.npz
# [Shadow 38] Found checkpoint at ./shadow_models/shadow_model_38.pth. Loading...
# [Shadow 39] Loaded existing indices from ./shadow_indices/shadow_indices_39.npz
# [Shadow 39] Found checkpoint at ./shadow_models/shadow_model_39.pth. Loading...
# [Shadow 40] Loaded existing indices from ./shadow_indices/shadow_indices_40.npz
# [Shadow 40] Found checkpoint at ./shadow_models/shadow_model_40.pth. Loading...
# [Shadow 41] Loaded existing indices from ./shadow_indices/shadow_indices_41.npz
# [Shadow 41] Found checkpoint at ./shadow_models/shadow_model_41.pth. Loading...
# [Shadow 42] Loaded existing indices from ./shadow_indices/shadow_indices_42.npz
# [Shadow 42] Found checkpoint at ./shadow_models/shadow_model_42.pth. Loading...
# [Shadow 43] Loaded existing indices from ./shadow_indices/shadow_indices_43.npz
# [Shadow 43] Found checkpoint at ./shadow_models/shadow_model_43.pth. Loading...
# [Shadow 44] Loaded existing indices from ./shadow_indices/shadow_indices_44.npz
# [Shadow 44] Found checkpoint at ./shadow_models/shadow_model_44.pth. Loading...
# [Shadow 45] Loaded existing indices from ./shadow_indices/shadow_indices_45.npz
# [Shadow 45] Found checkpoint at ./shadow_models/shadow_model_45.pth. Loading...
# [Shadow 46] Loaded existing indices from ./shadow_indices/shadow_indices_46.npz
# [Shadow 46] Found checkpoint at ./shadow_models/shadow_model_46.pth. Loading...
# [Shadow 47] Loaded existing indices from ./shadow_indices/shadow_indices_47.npz
# [Shadow 47] Found checkpoint at ./shadow_models/shadow_model_47.pth. Loading...
# [Shadow 48] Loaded existing indices from ./shadow_indices/shadow_indices_48.npz
# [Shadow 48] Found checkpoint at ./shadow_models/shadow_model_48.pth. Loading...
# [Shadow 49] Loaded existing indices from ./shadow_indices/shadow_indices_49.npz
# [Shadow 49] Found checkpoint at ./shadow_models/shadow_model_49.pth. Loading...
# [Shadow 50] Loaded existing indices from ./shadow_indices/shadow_indices_50.npz
# [Shadow 50] Found checkpoint at ./shadow_models/shadow_model_50.pth. Loading...
# [Shadow 51] Loaded existing indices from ./shadow_indices/shadow_indices_51.npz
# [Shadow 51] Found checkpoint at ./shadow_models/shadow_model_51.pth. Loading...
# [Shadow 52] Loaded existing indices from ./shadow_indices/shadow_indices_52.npz
# [Shadow 52] Found checkpoint at ./shadow_models/shadow_model_52.pth. Loading...
# [Shadow 53] Loaded existing indices from ./shadow_indices/shadow_indices_53.npz
# [Shadow 53] Found checkpoint at ./shadow_models/shadow_model_53.pth. Loading...
# [Shadow 54] Loaded existing indices from ./shadow_indices/shadow_indices_54.npz
# [Shadow 54] Found checkpoint at ./shadow_models/shadow_model_54.pth. Loading...
# [Shadow 55] Loaded existing indices from ./shadow_indices/shadow_indices_55.npz
# [Shadow 55] Found checkpoint at ./shadow_models/shadow_model_55.pth. Loading...
# [Shadow 56] Loaded existing indices from ./shadow_indices/shadow_indices_56.npz
# [Shadow 56] Found checkpoint at ./shadow_models/shadow_model_56.pth. Loading...
# [Shadow 57] Loaded existing indices from ./shadow_indices/shadow_indices_57.npz
# [Shadow 57] Found checkpoint at ./shadow_models/shadow_model_57.pth. Loading...
# [Shadow 58] Loaded existing indices from ./shadow_indices/shadow_indices_58.npz
# [Shadow 58] Found checkpoint at ./shadow_models/shadow_model_58.pth. Loading...
# [Shadow 59] Loaded existing indices from ./shadow_indices/shadow_indices_59.npz
# [Shadow 59] Found checkpoint at ./shadow_models/shadow_model_59.pth. Loading...
# [Shadow 60] Loaded existing indices from ./shadow_indices/shadow_indices_60.npz
# [Shadow 60] Found checkpoint at ./shadow_models/shadow_model_60.pth. Loading...
# [Shadow 61] Loaded existing indices from ./shadow_indices/shadow_indices_61.npz
# [Shadow 61] Found checkpoint at ./shadow_models/shadow_model_61.pth. Loading...
# [Shadow 62] Loaded existing indices from ./shadow_indices/shadow_indices_62.npz
# [Shadow 62] Found checkpoint at ./shadow_models/shadow_model_62.pth. Loading...
# [Shadow 63] Loaded existing indices from ./shadow_indices/shadow_indices_63.npz
# [Shadow 63] Found checkpoint at ./shadow_models/shadow_model_63.pth. Loading...

# %% [markdown]
# ### For each shadow model, create the member/non-member dataset

# %%
df_attack_total = []

for i, (shadow_model, train_idx, eval_idx, test_idx) in enumerate(shadow_models):
    # Rebuild DataLoaders from Membership dataset creation
    shadow_train_loader = create_subset_dataloader(
        trainset,
        train_idx,
        batch_size=config["dataset"]["train_batch_size"],
        shuffle=True,
        num_workers=config["dataset"]["num_workers"]
    )

    shadow_test_loader = create_subset_dataloader(
        trainset,
        eval_idx,
        batch_size=config["dataset"]["eval_batch_size"],
        shuffle=False,
        num_workers=config["dataset"]["num_workers"]
    )

    # Create the attack dataset for the shadow model
    df_attack = create_attack_dataset(
        shadow_model,
        shadow_train_loader,
        shadow_test_loader,
        device,
        output_dim=config["attack"]["output_dim"]
    )
    
    df_attack_total.append(df_attack)

    # Free GPU mem
    shadow_model.cpu()
    del shadow_model

df_attack_total = pd.concat(df_attack_total, ignore_index=True)
# Out:
# Member set: 100%|██████████| 10/10 [00:01<00:00,  7.80it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 11.19it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 24.29it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 10.61it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 23.87it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 10.19it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 22.79it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 10.34it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 21.82it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 11.36it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 23.36it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 11.60it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 23.81it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 10.83it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 20.77it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 10.45it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 21.97it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 10.84it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 23.42it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 10.33it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 21.53it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 10.35it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 22.45it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.99it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 20.30it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.90it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 20.20it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 10.06it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 22.28it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.57it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 20.28it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.52it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 19.80it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.69it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 20.59it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.66it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 19.75it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.30it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 18.62it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.49it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 19.25it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00, 10.22it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 19.57it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.57it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 20.29it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.34it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 19.31it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.00it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 19.55it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.63it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 16.75it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.22it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 20.17it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.87it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 18.54it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.80it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 18.65it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.27it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 19.31it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.08it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 20.38it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.96it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 18.68it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.80it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 18.34it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  7.34it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.39it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.69it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.99it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  7.97it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.73it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.43it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 18.56it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.75it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 18.40it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.68it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.36it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  9.10it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 16.95it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.72it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 18.41it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  7.47it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 13.52it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  7.65it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 12.87it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  7.44it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 16.05it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.46it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 18.63it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.54it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 16.38it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.18it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.07it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  7.51it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.54it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.44it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.82it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.13it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 18.21it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.60it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 15.78it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  7.97it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 16.08it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.36it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 16.29it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.45it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.57it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  7.84it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 15.55it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  6.92it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 14.58it/s]
# Non-member set: 100%|██████████| 5/5 [00:01<00:00,  4.83it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 16.35it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.35it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 16.17it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.13it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.56it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.28it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.53it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.09it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.68it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  7.76it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 17.08it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.38it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 16.18it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.19it/s]
# Member set: 100%|██████████| 10/10 [00:00<00:00, 16.83it/s]
# Non-member set: 100%|██████████| 5/5 [00:00<00:00,  8.07it/s]

# %% [markdown]
# ### Train (or load) the final MIA model

# %%
attack_save_dir = config["paths"]["attack_save_dir"]
os.makedirs(attack_save_dir, exist_ok=True)

attack_model_path = os.path.join(attack_save_dir, "attack_model.pth")

if os.path.exists(attack_model_path):
    print(f"Attack model found at {attack_model_path}. Loading...")
else:
    attack_model = train_attack_model(df_attack_total, config)
# Out:
# 0:	learn: 0.6393474	total: 70.1ms	remaining: 14s
# 1:	learn: 0.6074865	total: 86.9ms	remaining: 8.61s
# 2:	learn: 0.5880751	total: 103ms	remaining: 6.75s
# 3:	learn: 0.5762324	total: 122ms	remaining: 5.97s
# 4:	learn: 0.5689567	total: 144ms	remaining: 5.63s
# 5:	learn: 0.5651816	total: 161ms	remaining: 5.21s
# 6:	learn: 0.5633283	total: 178ms	remaining: 4.89s
# 7:	learn: 0.5620490	total: 193ms	remaining: 4.63s
# 8:	learn: 0.5610410	total: 209ms	remaining: 4.44s
# 9:	learn: 0.5600627	total: 226ms	remaining: 4.3s
# 10:	learn: 0.5595695	total: 250ms	remaining: 4.29s
# 11:	learn: 0.5591987	total: 267ms	remaining: 4.18s
# 12:	learn: 0.5588616	total: 293ms	remaining: 4.22s
# 13:	learn: 0.5587263	total: 321ms	remaining: 4.26s
# 14:	learn: 0.5585065	total: 342ms	remaining: 4.22s
# 15:	learn: 0.5584440	total: 367ms	remaining: 4.22s
# 16:	learn: 0.5583300	total: 385ms	remaining: 4.15s
# 17:	learn: 0.5582044	total: 406ms	remaining: 4.1s
# 18:	learn: 0.5581513	total: 423ms	remaining: 4.03s
# 19:	learn: 0.5581244	total: 437ms	remaining: 3.93s
# 20:	learn: 0.5580121	total: 452ms	remaining: 3.85s
# 21:	learn: 0.5578571	total: 468ms	remaining: 3.79s
# 22:	learn: 0.5577062	total: 485ms	remaining: 3.73s
# 23:	learn: 0.5576500	total: 504ms	remaining: 3.69s
# 24:	learn: 0.5575858	total: 531ms	remaining: 3.72s
# 25:	learn: 0.5574937	total: 550ms	remaining: 3.68s
# 26:	learn: 0.5574036	total: 566ms	remaining: 3.63s
# 27:	learn: 0.5573299	total: 596ms	remaining: 3.66s
# 28:	learn: 0.5572693	total: 620ms	remaining: 3.66s
# 29:	learn: 0.5572555	total: 651ms	remaining: 3.69s
# 30:	learn: 0.5571377	total: 674ms	remaining: 3.68s
# 31:	learn: 0.5570893	total: 698ms	remaining: 3.66s
# 32:	learn: 0.5570660	total: 725ms	remaining: 3.67s
# 170:	learn: 0.5542542	total: 3.39s	remaining: 575ms
# 171:	learn: 0.5542452	total: 3.41s	remaining: 555ms
# 172:	learn: 0.5542209	total: 3.43s	remaining: 535ms
# 173:	learn: 0.5542197	total: 3.44s	remaining: 515ms
# 174:	learn: 0.5542130	total: 3.46s	remaining: 495ms
# 175:	learn: 0.5542027	total: 3.49s	remaining: 476ms
# 176:	learn: 0.5541904	total: 3.51s	remaining: 456ms
# 177:	learn: 0.5541802	total: 3.52s	remaining: 435ms
# 178:	learn: 0.5541732	total: 3.54s	remaining: 415ms
# 179:	learn: 0.5541560	total: 3.56s	remaining: 395ms
# 180:	learn: 0.5541451	total: 3.57s	remaining: 375ms
# 181:	learn: 0.5541379	total: 3.59s	remaining: 355ms
# 182:	learn: 0.5541298	total: 3.6s	remaining: 335ms
# 183:	learn: 0.5541169	total: 3.62s	remaining: 315ms
# 184:	learn: 0.5541112	total: 3.64s	remaining: 295ms
# 185:	learn: 0.5541077	total: 3.66s	remaining: 276ms
# 186:	learn: 0.5540972	total: 3.69s	remaining: 257ms
# 187:	learn: 0.5540892	total: 3.71s	remaining: 237ms
# 188:	learn: 0.5540726	total: 3.72s	remaining: 217ms
# 189:	learn: 0.5540660	total: 3.74s	remaining: 197ms
# 190:	learn: 0.5540589	total: 3.76s	remaining: 177ms
# 191:	learn: 0.5540511	total: 3.77s	remaining: 157ms
# 192:	learn: 0.5540452	total: 3.79s	remaining: 138ms
# 193:	learn: 0.5540339	total: 3.81s	remaining: 118ms
# 194:	learn: 0.5540284	total: 3.83s	remaining: 98.1ms
# 195:	learn: 0.5540252	total: 3.84s	remaining: 78.4ms
# 196:	learn: 0.5540141	total: 3.86s	remaining: 58.7ms
# 197:	learn: 0.5540076	total: 3.87s	remaining: 39.1ms
# 198:	learn: 0.5540065	total: 3.9s	remaining: 19.6ms
# 199:	learn: 0.5539910	total: 3.92s	remaining: 0us
# [Attack Model] Accuracy: 0.7153, Precision: 0.6740, Recall: 0.8329, F1: 0.7450
# [Attack Model] AUC: 0.7688
# [Attack Model] ROC curve saved to ./assets
# [Attack Model] Saved to ./attack/catboost_attack_CatBoostClassifier_0.7153

# %%
from mia_lib.attack.oslo_attack import run_oslo_attack
# take first (or any other) shadow model as surrogate network
source_model = shadow_models[0][0].to(device)
source_model.eval()

results = run_oslo_attack(
    config,
    target_model=target_model,
    source_model=shadow_models[0][0],
    train_loader=trainloader,
    test_loader=testloader,
    device=device
)
# Out:
# [OSLO] Generating adversarial samples on 'member' dataset...
# OSLO Adversarial Gen: 100%|██████████| 196/196 [03:26<00:00,  1.05s/it]
# [OSLO] Generating adversarial samples on 'non-member' dataset...
# OSLO Adversarial Gen: 100%|██████████| 20/20 [00:46<00:00,  2.33s/it]
# [OSLO] Confusion Matrix:
#  [[ 6652  3348]
#  [36444 13556]]
# [OSLO] Metrics: Precision: 0.8019, Recall: 0.2711, F1: 0.4052, Accuracy: 0.3368
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
